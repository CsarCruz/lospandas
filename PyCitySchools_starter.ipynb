# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
can_csv = "Sources/CAvideos.csv"

# Read School and Student Data File and store into Pandas DataFrames

CAN_df = pd.read_csv(can_csv)
CAN_df = can_df[["trending_date","title","channel_title","category_id","publish_time","tags","views","likes","dislikes","comment_count"]]
CAN_df['Country'] = "CAN"
CAN_df.head()






# # Combine the data into a single dataset.  
# school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
# school_data_complete.head()
# # school_data.head()
# student_data.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3      17.14.11                           I Dare You: GOING BALD!?
# 4      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV           23  2017-11-13T17:00:00.000Z
# 2  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3      nigahiga           24  2017-11-12T18:01:41.000Z
# 4    Ed Sheeran           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# ...

# %%
CAN_df["category_id"] = CAN_df["category_id"].replace(1,"Film & Animation")

can_categories = CAN_df.groupby(["category_id"]).sum()
can_categories = can_categories.sort_values("views", ascending=False)
can_categories


can_categories
# Out:
# C:\Users\jlozan02\AppData\Local\Temp\ipykernel_17000\22109053.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   can_categories = CAN_df.groupby(["category_id"]).sum()
#                         views      likes  dislikes  comment_count
# category_id
# 24                13671215509  387245433  25791583       55313036
# Music             13179850194  564447530  22098190       52435252
# 23                 3708438785  196046674   5372515       19638776
# 22                 3228227926  105388564   9480796       16818201
# 17                 2997652188   59449419   3286369        7661342
# Film & Animation   2939060844   77802003   3111259       10086573
# 25                 1614610043   32705054   3264041        9259788
# 26                 1570846611   51183104   1730520        8342917
# ...
