# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
frpath= "FRvideos.csv"
france = pd.read_csv(frpath)
francedf=pd.DataFrame(france)
francedf['country'] = 'FRANCE'
francedf.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
# 2           23  2017-11-13T17:00:38.000Z
# 3           20  2017-11-12T17:00:02.000Z
# 4           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
gbpath= "GBvideos.csv"
gb = pd.read_csv(gbpath)
gbdf=pd.DataFrame(gb)
gbdf['country'] = 'GREAT BRITAIN'
gbdf.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
uspath= "USvideos.csv"
us = pd.read_csv(uspath)
usdf=pd.DataFrame(us)
usdf['country'] = 'UNITED STATES'
usdf.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
depath= "DEvideos.csv"
de = pd.read_csv(depath)
dedf=pd.DataFrame(de)
dedf['country'] = 'GERMANY'
dedf.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:08:49.000Z
# 1           23  2017-11-12T22:30:01.000Z
# 2           24  2017-11-13T07:30:00.000Z
# 3           27  2017-11-12T15:00:01.000Z
# 4           24  2017-11-12T13:10:36.000Z
#
# ...

# %%
capath= "CAvideos.csv"
ca = pd.read_csv(capath)
cadf=pd.DataFrame(ca)
cadf['country'] = 'CANADA'
cadf.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
new=pd.concat([francedf,gbdf,dedf])

newdf=new[["trending_date","title","channel_title","category_id","publish_time","tags","views","likes","dislikes","comment_count","country"]]
newdf.head()
# Out:
#   trending_date                                              title  \
# 0      17.14.11           Malika LePen : Femme de Gauche - Trailer
# 1      17.14.11  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...
# 2      17.14.11  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...
# 3      17.14.11                    PAPY GRENIER - METAL GEAR SOLID
# 4      17.14.11  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...
#
#          channel_title  category_id              publish_time  \
# 0  Le Raptor Dissident           24  2017-11-13T17:32:55.000Z
# 1              Le Labo           24  2017-11-12T15:00:02.000Z
# 2      Daniil le Russe           23  2017-11-13T17:00:38.000Z
# 3    Joueur Du Grenier           20  2017-11-12T17:00:02.000Z
# 4    Aurelien Fontenoy           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# 0  Raptor"|"Dissident"|"Expliquez"|"moi"|"cette"|...  212702  29282      1108
# ...

# %%
newdf["category_id"] = newdf["category_id"].replace(1,"Film & Animation")
newdf["category_id"] = newdf["category_id"].replace(2,"Autos & Vehiles")
newdf["category_id"] = newdf["category_id"].replace(10,"Music")
newdf["category_id"] = newdf["category_id"].replace(15,"Pets & Animals")
newdf["category_id"] = newdf["category_id"].replace(17,"Sports")
newdf["category_id"] = newdf["category_id"].replace(18,"Short Movies")
newdf["category_id"] = newdf["category_id"].replace(19,"Travel & Events")
newdf["category_id"] = newdf["category_id"].replace(20,"Gaming")
newdf["category_id"] = newdf["category_id"].replace(21,"Videoblogging")
newdf["category_id"] = newdf["category_id"].replace(22,"People & Blogs")
newdf["category_id"] = newdf["category_id"].replace(23,"Comedy")
newdf["category_id"] = newdf["category_id"].replace(24,"Entertainment")
newdf["category_id"] = newdf["category_id"].replace(25,"News & Politics")
newdf["category_id"] = newdf["category_id"].replace(26,"How to & Style")
newdf["category_id"] = newdf["category_id"].replace(27,"Education")
newdf["category_id"] = newdf["category_id"].replace(28,"Science & Technology")
newdf["category_id"] = newdf["category_id"].replace(29,"No profits & Activism")
newdf["category_id"] = newdf["category_id"].replace(30,"Movies")
newdf["category_id"] = newdf["category_id"].replace(31,"Anime/Animation")
newdf["category_id"] = newdf["category_id"].replace(32,"Action/Adventure")
newdf["category_id"] = newdf["category_id"].replace(33,"Classic")
newdf["category_id"] = newdf["category_id"].replace(34,"Comedy")
newdf["category_id"] = newdf["category_id"].replace(35,"Documentary")
newdf["category_id"] = newdf["category_id"].replace(36,"Drama")
newdf["category_id"] = newdf["category_id"].replace(37,"Family")
newdf["category_id"] = newdf["category_id"].replace(38,"Foreign")
newdf["category_id"] = newdf["category_id"].replace(40,"Sci-Fi/Fantasy")
newdf["category_id"] = newdf["category_id"].replace(41,"Thriller")
newdf["category_id"] = newdf["category_id"].replace(42,"Shorts")
newdf["category_id"] = newdf["category_id"].replace(43,"Shows")
newdf["category_id"] = newdf["category_id"].replace(44,"Trailers")
newdf.head()
# Out:
# /Users/cesarcruz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/cesarcruz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/cesarcruz/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
category_count = newdf["category_id"].unique()
category_count
# Out:
# array(['Entertainment', 'Comedy', 'Gaming', 'Sports', 'People & Blogs',
#        'Education', 'How to & Style', 'Science & Technology',
#        'Autos & Vehiles', 'News & Politics', 'Film & Animation', 'Music',
#        'Shows', 'Travel & Events', 'Pets & Animals',
#        'No profits & Activism', 'Movies', 'Trailers'], dtype=object)

# %%
newdf.to_csv("newdb.csv")
